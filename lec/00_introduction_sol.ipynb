# %% [markdown]
# # Introduction to Computer Programming and Numerical Methods
#
# > **Mohamad M. Hallal, PhD** <br> Teaching Professor, UC Berkeley
#
# [![License](https://img.shields.io/badge/license-CC%20BY--NC--ND%204.0-blue)](https://creativecommons.org/licenses/by-nc-nd/4.0/)
# ***

# %% [markdown]
# # Introduction
#
# 1. [**Computer Programming**](#s1)
#
# ***

# %% [markdown]
# # 0. Motivation
#
# An *algorithm* is a sequence of well-defined, computer-implementable instructions, typically to solve a problem or to perform a computation.
#
# **Learning objectives:**
#
# * Explain what an algorithm is
# * Give examples of algorithms
# * Appreciate the value of algorithms and computer programming

# %% [markdown]
# # 1. Computer Programming <a id="s1"></a>
#
# Computer programming is the process of writing code (aka, coding) to instruct a computer to accomplish a specific task. These tasks can be as simple as performing a mathematical calculation. They can also be as complex as reading data from a file to perform data analysis, simulating an automotive design, simulating the structural response of a bridge to an earthquake, among others.

# %% [markdown]
# ## 1.1. Simple Algorithm
#
# We can use computer programming to perform simple calculations.
#
# <div class="alert alert-block alert-info"> <b>TRY IT!</b> Compute $1 + 2$ in the cell below.</div>

# %%
1 + 2
# Out:
# 3

# %% [markdown]
# ## 1.2. More Complex Algorithm
#
# Computer programming can dramatically elevate the quality and efficiency of your work by performing more complex tasks.
#
# <div class="alert alert-block alert-info"> <b>TRY IT!</b> Read the file <code>'resources/engin7_roster.csv'</code>.</div>

# %%
# import pandas
import pandas as pd

# read csv file using pd.read_csv()
df = pd.read_csv('resources/engin7_roster.csv')

# show first few rows
df.head()
# Out:
#    Number                       Major 1 Major 2  Terms
# 0       1     Mechanical Engineering BS     NaN      3
# 1       2       Chemical Engineering BS     NaN      5
# 2       3     Mechanical Engineering BS     NaN      7
# 3       4     Mechanical Engineering BS     NaN      7
# 4       5  Industrial Eng & Ops Rsch BS     NaN      7

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>TRY IT!</b> Group students based on their <code>'Major 1'</code>.</div>

# %%
# grouping and counting entries in each major using df.groupby(['group'])['group'].count()
df_grouped = df.groupby(['Major 1'])['Major 1'].count()
df_grouped
# Out:
# Major 1
# Aerospace Engineering BS        19
# Analytics BA                     1
# Applied Mathematics BA           4
# Architecture BA                  2
# Astrophysics BA                  1
# Bioengineering BS               28
# Business Administration BS      10
# CNR Undeclared UG                1
# Chemical Biology BS              1
# Chemical Engineering BS         42
# Chemistry BS                     3
# Civil Engineering BS            66
# Conserv & Resource Stds BS       1
# Electrical Eng & Comp Sci BS     2
# Energy Engineering BS            9
# Eng Math & Statistics BS         3
# Engineering Physics BS           1
# Engineering Undeclared UG       11
# Environmental Engin Sci  BS     14
# Environmental Sciences BS        3
# Genetics & Plant Biology BS      2
# Industrial Eng & Ops Rsch BS    21
# Landscape Architecture BA        1
# Legal Studies BA                 1
# Letters & Sci Undeclared UG     54
# Materials Science & Eng BS      20
# Mathematics BA                   2
# Mechanical Engineering BS       85
# Nuclear Engineering BS          23
# Physics BA                       1
# Political Science BA             1
# Statistics BA                    1
# Name: Major 1, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>TRY IT!</b> Plot a bar chart of students based on their <code>'Major 1'</code>.</div>

# %%
# plotting bar chart
df_grouped_sorted = df_grouped.sort_values(ascending=True) 
df_grouped.plot.barh(x='Major 1', figsize=(5,7))
# Out:
# <Axes: ylabel='Major 1'>

# %% [markdown]
# ## 1.3. Reasons to Learn Programming
#
# * Programming compels you to uncover your underlying logic and fosters transparency
# * It prompts you to structure your work systematically, facilitating sharing with others
# * It makes your work reproducible
#
# By employing your programs repeatedly, you can efficiently navigate mundane tasks and optimize your productivity.
#
# *All scientists and engineers should learn how to code – it will transform you*.
#
# <div class="alert alert-block alert-info"> <b>TRY IT!</b> Repeat the above for <code>'civeng93_roster.csv'</code>.</div>

# %%
# import pandas
import pandas as pd

# read csv file using pd.read_csv()
df = pd.read_csv('resources/civeng93_roster.csv')

# show first few rows
df.head()
# Out:
#    Number                      Major 1       Major 2  Terms
# 0       1              Data Science BA  Economics BA      8
# 1       2                 Economics BA           NaN      7
# 2       3         Political Economy BA           NaN      8
# 3       4  Letters & Sci Undeclared UG           NaN      8
# 4       5  Letters & Sci Undeclared UG           NaN      8

# %%
# grouping and counting entries in each major using df.groupby(['group'])['group'].count()
df_grouped = df.groupby(['Major 1'])['Major 1'].count()
df_grouped
# Out:
# Major 1
# Aerospace Engineering BS       10
# Architecture BA                 1
# Astrophysics BA                 1
# Atmospheric Science BA          1
# Business Administration BS      2
# Chemical Biology BS             1
# Chemical Engineering BS         1
# Civil Engineering BS           41
# Conserv & Resource Stds BS      1
# Data Science BA                 1
# Economics BA                    6
# Energy Engineering BS           6
# Eng Math & Statistics BS        1
# Engineering Undeclared UG       2
# Environ Econ & Policy BS        3
# Environmental Engin Sci  BS     1
# Environmental Sciences BS       1
# Geography BA                    1
# Global Studies BA               1
# Letters & Sci Undeclared UG    13
# Molecular & Cell Biology BA     1
# Physics BA                      1
# Political Economy BA            1
# Society and Environment BS      1
# Name: Major 1, dtype: int64
